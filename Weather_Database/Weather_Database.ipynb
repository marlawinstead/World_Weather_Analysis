# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high = 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
cities
# Out:
# ['ushuaia',
#  'mataura',
#  'hermanus',
#  'kidal',
#  'nouadhibou',
#  'broome',
#  'chokurdakh',
#  'jamestown',
#  'bethel',
#  'east london',
#  'kapaa',
#  'moron',
#  'sao joao da barra',
#  'bluff',
#  'sentyabrskiy',
#  'nizhneyansk',
#  'coahuayana',
#  'bredasdorp',
#  'port elizabeth',
#  'rikitea',
#  'illoqqortoormiut',
#  'sistranda',
#  'tabiauea',
#  'albany',
#  'arraial do cabo',
#  'tsihombe',
#  'hilo',
#  'castro',
#  'salalah',
#  'mersing',
#  'yuancheng',
#  'norman wells',
#  'sobolevo',
#  'carnarvon',
#  'halalo',
#  'el mahalla el kubra',
#  'grand river south east',
#  'mahebourg',
#  'yellowknife',
#  'cape town',
#  'marsh harbour',
#  'barcelos',
#  'vaini',
#  'olafsvik',
#  'veraval',
#  'berezovyy',
#  'cabo san lucas',
#  'san jose',
#  'geraldton',
#  'guerrero negro',
#  'pingliang',
#  'punta arenas',
#  'samusu',
#  'pevek',
#  'mount darwin',
#  'jiangyou',
#  'gillette',
#  'faya',
#  'busselton',
#  'port alfred',
#  'staryy nadym',
#  'ambanja',
#  'barentsburg',
#  'amderma',
#  'new norfolk',
#  'tiznit',
#  'lata',
#  'blagoveshchensk',
#  'umm kaddadah',
#  'lavrentiya',
#  'khatanga',
#  'luangwa',
#  'dinghai',
#  'aklavik',
#  'comodoro rivadavia',
#  'nuuk',
#  'barrow',
#  'attawapiskat',
#  'chumikan',
#  'lolua',
#  'port lincoln',
#  'almaznyy',
#  'atuona',
#  'faanui',
#  'montevideo',
#  'huesca',
#  'mys shmidta',
#  'boca do acre',
#  'upernavik',
#  'avarua',
#  'hobart',
#  'alotau',
#  'bocanda',
#  'ribeira grande',
#  'souillac',
#  'saint-philippe',
#  'chagda',
#  'ust-kamchatsk',
#  'kodiak',
#  'gamba',
#  'nikolskoye',
#  'raudeberg',
#  'skalistyy',
#  'belushya guba',
#  'hasaki',
#  'provideniya',
#  'saldanha',
#  'ifakara',
#  'sandy bay',
#  'tuktoyaktuk',
#  'butaritari',
#  'beringovskiy',
#  'sitka',
#  'elbistan',
#  'wonopringgo',
#  'taolanaro',
#  'mus',
#  'torbay',
#  'valle de allende',
#  'bengkulu',
#  'jaleswar',
#  'deputatskiy',
#  'tumannyy',
#  'correntina',
#  'kipini',
#  'moose factory',
#  'weinan',
#  'skibbereen',
#  'tamesis',
#  'victoria',
#  'shizuishan',
#  'mantua',
#  'airai',
#  'pangoa',
#  'anloga',
#  'srivardhan',
#  'qaanaaq',
#  'nemuro',
#  'kegayli',
#  'evora',
#  'puerto ayora',
#  'mrirt',
#  'tongliao',
#  'mosetse',
#  'great yarmouth',
#  'waqqas',
#  'sorland',
#  'lebu',
#  'amuntai',
#  'aqtobe',
#  'nome',
#  'karasjok',
#  'linqiong',
#  'san cristobal',
#  'morondava',
#  'russellville',
#  'bambous virieux',
#  'luderitz',
#  'senigallia',
#  'vardo',
#  'udachnyy',
#  'guerrero',
#  'ucluelet',
#  'charleston',
#  'kahului',
#  'osoyoos',
#  'henties bay',
#  'trat',
#  'rio gallegos',
#  'manicore',
#  'makakilo city',
#  'artyk',
#  'saint george',
#  'misratah',
#  'irmo',
#  'bay roberts',
#  'djambala',
#  'abeche',
#  'burkhala',
#  'beohari',
#  'okato',
#  'asau',
#  'chuy',
#  'mar del plata',
#  'acurenam',
#  'nanyang',
#  'boende',
#  'georgetown',
#  'westport',
#  'salinopolis',
#  'athabasca',
#  'kamaishi',
#  'campeche',
#  'vestmanna',
#  'ruidoso',
#  'boden',
#  'ukiah',
#  'merrill',
#  'corinto',
#  'vila velha',
#  'maniitsoq',
#  'dicabisagan',
#  'christchurch',
#  'gat',
#  'xadani',
#  'amboasary',
#  'pisco',
#  'longyearbyen',
#  'adrar',
#  'sotouboua',
#  'nguiu',
#  'idrinskoye',
#  'ascension',
#  'tulum',
#  'zainsk',
#  'husavik',
#  'cabedelo',
#  'cayenne',
#  'kaitangata',
#  'kirakira',
#  'esperance',
#  'rutana',
#  'zhangye',
#  'viransehir',
#  'byron bay',
#  'zwedru',
#  'meyungs',
#  'narsaq',
#  'dikson',
#  'ndola',
#  'ayan',
#  'talaya',
#  'neuquen',
#  'ponta do sol',
#  'port-cartier',
#  'codrington',
#  'vila franca do campo',
#  'alexandria',
#  'khandbari',
#  'seddon',
#  'vilhena',
#  'katsuura',
#  'leningradskiy',
#  'novotalitsy',
#  'sandwick',
#  'tiksi',
#  'kavieng',
#  'bosanski novi',
#  'vylkove',
#  'ayios matthaios',
#  'aykhal',
#  'whitehorse',
#  'hithadhoo',
#  'denpasar',
#  'ulaangom',
#  'yulara',
#  'waitara',
#  'brigantine',
#  'melita',
#  'puerto del rosario',
#  'nanlong',
#  'coquimbo',
#  'san clemente',
#  'thunder bay',
#  'geresk',
#  'madison',
#  'rawannawi',
#  'svetlogorsk',
#  'viedma',
#  'nizhniy baskunchak',
#  'naryan-mar',
#  'astoria',
#  'thompson',
#  'cidreira',
#  'bolungarvik',
#  'namibe',
#  'kogon',
#  'buala',
#  'jalu',
#  'dwarka',
#  'dolbeau',
#  'san ramon',
#  'alofi',
#  'beni mazar',
#  'beloha',
#  'muros',
#  'poum',
#  'umm ruwabah',
#  'tasiilaq',
#  'west plains',
#  'mogadishu',
#  'zhuhai',
#  'arua',
#  'kholm',
#  'mount gambier',
#  'omutinskoye',
#  'soyo',
#  'ocara',
#  'otjimbingwe',
#  'kuusamo',
#  'san patricio',
#  'ostrovnoy',
#  'skjervoy',
#  'clyde river',
#  'severo-kurilsk',
#  'dingle',
#  'filingue',
#  'mullaitivu',
#  'sembe',
#  'oxford',
#  'eucaliptus',
#  'healdsburg',
#  'zhigansk',
#  'mareeba',
#  'kudahuvadhoo',
#  'tasbuget',
#  'meulaboh',
#  'ulagan',
#  'pangnirtung',
#  'rawson',
#  'taoudenni',
#  'ust-kuyga',
#  'aripuana',
#  'feira de santana',
#  'hofn',
#  'kelso',
#  'port shepstone',
#  'lorengau',
#  'simplicio mendes',
#  'iqaluit',
#  'dustlik',
#  'taos',
#  'vostok',
#  'sao filipe',
#  'tuatapere',
#  'margate',
#  'kimbe',
#  'mount pleasant',
#  'petropavlovsk-kamchatskiy',
#  'mount isa',
#  'ngukurr',
#  'honiara',
#  'banjar',
#  'roma',
#  'yian',
#  'havre-saint-pierre',
#  'lota',
#  'taga',
#  'lakselv',
#  'port blair',
#  'laguna',
#  'aswan',
#  'gbarnga',
#  'flin flon',
#  'sechura',
#  'sibu',
#  'kathmandu',
#  'bridlington',
#  'vestmannaeyjar',
#  'kangaba',
#  'opuwo',
#  'yerofey pavlovich',
#  'saleaula',
#  'homberg',
#  'easton',
#  'raga',
#  'hamilton',
#  'karaul',
#  'tlaxco',
#  'russell',
#  'rocha',
#  'stantsionno-oyashinskiy',
#  'kalisz',
#  'saskylakh',
#  'nogliki',
#  'dzilam gonzalez',
#  'leeuwarden',
#  'shubarkuduk',
#  'sao jose da coroa grande',
#  'hualmay',
#  'puerto escondido',
#  'morgan city',
#  'talnakh',
#  'harper',
#  'akhalgori',
#  'launceston',
#  'avera',
#  'inhambane',
#  'nantucket',
#  'lompoc',
#  'bud',
#  'sarangani',
#  'espanola',
#  'kununurra',
#  'kakonko',
#  'mackay',
#  'rungata',
#  'maxixe',
#  'sola',
#  'kieta',
#  'kamenskiy',
#  'te anau',
#  'college',
#  'itarema',
#  'lakes entrance',
#  'karaton',
#  'bathsheba',
#  'listvyanka',
#  'isangel',
#  'cape canaveral',
#  'seoul',
#  'tsuruoka',
#  'qandala',
#  'pemberton',
#  'camopi',
#  'krasnoselkup',
#  'kissidougou',
#  'da nang',
#  'yerbogachen',
#  'tambopata',
#  'brenham',
#  'saint-joseph',
#  'seleron',
#  'bria',
#  'palabuhanratu',
#  'uusikaupunki',
#  'terney',
#  'sabang',
#  'la reforma',
#  'yayva',
#  'paracuru',
#  'cockburn town',
#  'tromso',
#  'kumluca',
#  'talawdi',
#  'buraydah',
#  'fortuna',
#  'howard springs',
#  'kyshtovka',
#  'champerico',
#  'korla',
#  'cherskiy',
#  'virginia beach',
#  'nara',
#  'dakar',
#  'pokhara',
#  'batagay-alyta',
#  'tura',
#  'manadhoo',
#  'tessalit',
#  'aketi',
#  'newport',
#  'annau',
#  'fairview shores',
#  'ust-ilimsk',
#  'sofiysk',
#  'katobu',
#  'klaksvik',
#  'belyy yar',
#  'constitucion',
#  'namatanai',
#  'palafrugell',
#  'ayagoz',
#  'bakel',
#  'katangli',
#  'cap-aux-meules',
#  'tilichiki',
#  'rassvet',
#  'revuca',
#  'ilulissat',
#  'fort nelson',
#  'samarai',
#  'ituni',
#  'zelenoborskiy',
#  'manokwari',
#  'bolshoy tsaryn',
#  'jambi',
#  'vao',
#  'linjiang',
#  'san bartolome de tirajana',
#  'lagoa',
#  'marcona',
#  'macon',
#  'alekseyevsk',
#  'sagua de tanamo',
#  'smithers',
#  'cabra',
#  'camacha',
#  'kloulklubed',
#  'acapulco',
#  'kemijarvi',
#  'thaba nchu',
#  'labuhan',
#  'polewali',
#  'bocaranga',
#  'lamu',
#  'puerto ayacucho',
#  'candelaria',
#  'kitimat',
#  'okahandja',
#  'general pico',
#  'kampot',
#  'shimoda',
#  'atar',
#  'houma',
#  'lima',
#  'bajil',
#  'santiago del estero',
#  'trowbridge',
#  'pafos',
#  'thinadhoo',
#  'papara',
#  'san angelo',
#  'lindi',
#  'amga',
#  'manoel urbano',
#  'hovd',
#  'malihabad',
#  'shingu',
#  'baykit',
#  'ancud',
#  'portland',
#  'kruisfontein',
#  'umzimvubu',
#  'poronaysk',
#  'bulalacao',
#  'akyab',
#  'khash',
#  'careiro da varzea',
#  'xinan',
#  'taybad',
#  'kincardine',
#  'riyadh',
#  'bembereke',
#  'wahiawa',
#  'igaracu do tiete',
#  'lichtenburg',
#  'ushibuka',
#  'charters towers',
#  'khasan',
#  'wajid',
#  'bilma',
#  'yatou',
#  'los llanos de aridane',
#  'puerto madero',
#  'buchanan',
#  'seabra',
#  'sibolga',
#  'macia',
#  'safaga',
#  'creston',
#  'caconda',
#  'aljezur',
#  'coihaique',
#  'ventspils',
#  'egvekinot',
#  'san pedro',
#  'evensk',
#  'micheweni',
#  'kenai',
#  'leon',
#  'san juan bautista',
#  'sandavagur',
#  'gimli',
#  'tarakan',
#  'komsomolskiy',
#  'san matias',
#  'gayeri',
#  'bhikhi',
#  'sergeyevka',
#  'porto walter',
#  'buin',
#  'praya',
#  'zonguldak',
#  'satitoa',
#  'viseu',
#  'paka',
#  'yarada',
#  'sioux lookout',
#  'tingi',
#  'nichinan',
#  'sheridan',
#  'svetlyy',
#  'najran',
#  'wamba',
#  'phan rang',
#  'chala',
#  'guamuchil',
#  'maningrida',
#  'fare',
#  'santa isabel',
#  'moreira sales',
#  'harlingen',
#  'kaspiyskiy',
#  'solnechnyy',
#  'novoagansk',
#  'buritis',
#  'marshfield',
#  'verin',
#  'bowen',
#  'lumsden',
#  'vaitupu',
#  'lagos',
#  'pemangkat',
#  'palkaka',
#  'porto novo',
#  'menongue',
#  'vetlanda',
#  'port hardy',
#  'flinders',
#  'necochea',
#  'mastung',
#  'psedakh',
#  'port moresby',
#  'northam',
#  'nilo',
#  'san lawrenz',
#  'catamarca',
#  'omsukchan',
#  'unai',
#  'ruatoria',
#  'durban',
#  'carballo',
#  'jiamusi',
#  'urumqi',
#  'biak',
#  'ust-tsilma',
#  'longlac',
#  'paradwip',
#  'siemiatycze',
#  'islampur',
#  'port hedland',
#  'pueblo',
#  'pyinmana',
#  'gushikawa',
#  'luzzi',
#  'serebryansk',
#  'sisimiut',
#  'broken hill',
#  'bonavista',
#  'birin',
#  'messina',
#  'buncrana',
#  'kaduy',
#  'saint-pierre',
#  'berlevag',
#  'andra',
#  'hirara',
#  'manta',
#  'floro',
#  'tabialan',
#  'bur gabo',
#  'sawakin',
#  'bertoua',
#  'upanema',
#  'nyurba',
#  'jibuti',
#  'bintulu',
#  'naze',
#  'terre-de-bas',
#  'turukhansk',
#  'pachino',
#  'chanderi',
#  'louisbourg',
#  'wajir',
#  'laem sing',
#  'kamenskoye',
#  'sawtell',
#  'aragarcas',
#  'kalabo',
#  'houston',
#  'mwinilunga',
#  'praia da vitoria',
#  'touros',
#  'kofele',
#  'babstovo',
#  'anan',
#  'tazovskiy',
#  'rusape',
#  'kanigoro',
#  'arraias',
#  'sambava',
#  'mehamn',
#  'araouane',
#  'bandrele',
#  'ovalle',
#  'garden city',
#  'ciudad bolivar',
#  'havelock',
#  'tuggurt',
#  'cape coast',
#  'montepuez',
#  'saa',
#  'altagracia de orituco',
#  'genhe',
#  'moreira',
#  'kaura namoda',
#  'maraa',
#  'ugoofaaru',
#  'goundi',
#  'alpena',
#  'varca',
#  'fuerte olimpo',
#  'pogar',
#  'esna',
#  'karauzyak',
#  'coxquihui',
#  'santa eulalia del rio',
#  'noumea',
#  'stuttgart',
#  'ovsyanka',
#  'paide',
#  'azare',
#  'mae hong son',
#  'la ermita',
#  'paz de ariporo',
#  'wagar',
#  'ola',
#  'grafton',
#  'cheremukhovo',
#  'abohar',
#  'cumberland',
#  'hervey bay',
#  'ocampo',
#  'aktash',
#  'wundanyi',
#  'ushtobe',
#  'wardha',
#  'vreed en hoop',
#  'southbridge',
#  'tsagan aman',
#  'mukhen',
#  'marinette',
#  'tharrawaddy',
#  'liverpool',
#  'valparaiso',
#  'roebourne',
#  'la ronge',
#  'sweetwater',
#  'enumclaw',
#  'ambulu',
#  'dunedin',
#  'manakara',
#  'porto velho',
#  'ahipara',
#  'katherine',
#  'nanortalik',
#  'caravelas',
#  'porto torres',
#  'santo amaro da imperatriz',
#  'paamiut',
#  'zharkent',
#  'manaus',
#  'ape',
#  'kailua',
#  'mandalgovi',
#  'benguela',
#  'valdivia',
#  'fountain hills',
#  'chadiza',
#  'dahra']

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + "ushuaia"

# %%
city_weather = requests.get(city_url).json()
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_description = city_weather["weather"][0]["description"]
city_country = city_weather["sys"]["country"]
city_weather
# Out:
# {'coord': {'lon': -68.3, 'lat': -54.8},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 51.46,
#   'feels_like': 49.41,
#   'temp_min': 51.46,
#   'temp_max': 51.46,
#   'pressure': 998,
#   'humidity': 66},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 75},
#  'dt': 1650229163,
#  'sys': {'type': 1,
#   'id': 8303,
#   'country': 'AR',
#   'sunrise': 1650194854,
#   'sunset': 1650231451},
#  'timezone': -10800,
#  'id': 3833367,
#  'name': 'Ushuaia',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | kidal
# Processing Record 5 of Set 1 | nouadhibou
# Processing Record 6 of Set 1 | broome
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | moron
# Processing Record 13 of Set 1 | sao joao da barra
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | coahuayana
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | sistranda
# Processing Record 23 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | salalah
# Processing Record 30 of Set 1 | mersing
# Processing Record 31 of Set 1 | yuancheng
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | sobolevo
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 1 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | marsh harbour
# Processing Record 42 of Set 1 | barcelos
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | olafsvik
# Processing Record 45 of Set 1 | veraval
# Processing Record 46 of Set 1 | berezovyy
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | san jose
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | pingliang
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | mount darwin
# Processing Record 6 of Set 2 | jiangyou
# Processing Record 7 of Set 2 | gillette
# Processing Record 8 of Set 2 | faya
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | staryy nadym
# Processing Record 12 of Set 2 | ambanja
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | tiznit
# Processing Record 17 of Set 2 | lata
# Processing Record 18 of Set 2 | blagoveshchensk
# Processing Record 19 of Set 2 | umm kaddadah
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | luangwa
# Processing Record 23 of Set 2 | dinghai
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | comodoro rivadavia
# Processing Record 26 of Set 2 | nuuk
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | chumikan
# Processing Record 30 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | almaznyy
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | montevideo
# Processing Record 36 of Set 2 | huesca
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | boca do acre
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 2 | bocanda
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | gamba
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | raudeberg
# Processing Record 3 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | hasaki
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | saldanha
# Processing Record 8 of Set 3 | ifakara
# Processing Record 9 of Set 3 | sandy bay
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | beringovskiy
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | elbistan
# Processing Record 15 of Set 3 | wonopringgo
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | mus
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | valle de allende
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | jaleswar
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | correntina
# Processing Record 25 of Set 3 | kipini
# Processing Record 26 of Set 3 | moose factory
# Processing Record 27 of Set 3 | weinan
# Processing Record 28 of Set 3 | skibbereen
# Processing Record 29 of Set 3 | tamesis
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | shizuishan
# Processing Record 32 of Set 3 | mantua
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | pangoa
# Processing Record 35 of Set 3 | anloga
# Processing Record 36 of Set 3 | srivardhan
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 3 | evora
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 3 | tongliao
# Processing Record 44 of Set 3 | mosetse
# Processing Record 45 of Set 3 | great yarmouth
# Processing Record 46 of Set 3 | waqqas
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | amuntai
# Processing Record 50 of Set 3 | aqtobe
# Processing Record 1 of Set 4 | nome
# Processing Record 2 of Set 4 | karasjok
# Processing Record 3 of Set 4 | linqiong
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | morondava
# Processing Record 6 of Set 4 | russellville
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | senigallia
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | udachnyy
# Processing Record 12 of Set 4 | guerrero
# Processing Record 13 of Set 4 | ucluelet
# Processing Record 14 of Set 4 | charleston
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | osoyoos
# Processing Record 17 of Set 4 | henties bay
# Processing Record 18 of Set 4 | trat
# Processing Record 19 of Set 4 | rio gallegos
# Processing Record 20 of Set 4 | manicore
# Processing Record 21 of Set 4 | makakilo city
# Processing Record 22 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | misratah
# Processing Record 25 of Set 4 | irmo
# Processing Record 26 of Set 4 | bay roberts
# Processing Record 27 of Set 4 | djambala
# Processing Record 28 of Set 4 | abeche
# Processing Record 29 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 30 of Set 4 | beohari
# Processing Record 31 of Set 4 | okato
# Processing Record 32 of Set 4 | asau
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | acurenam
# Processing Record 36 of Set 4 | nanyang
# Processing Record 37 of Set 4 | boende
# Processing Record 38 of Set 4 | georgetown
# Processing Record 39 of Set 4 | westport
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | athabasca
# Processing Record 42 of Set 4 | kamaishi
# Processing Record 43 of Set 4 | campeche
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | ruidoso
# Processing Record 46 of Set 4 | boden
# Processing Record 47 of Set 4 | ukiah
# Processing Record 48 of Set 4 | merrill
# Processing Record 49 of Set 4 | corinto
# Processing Record 50 of Set 4 | vila velha
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | dicabisagan
# Processing Record 3 of Set 5 | christchurch
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 6 of Set 5 | amboasary
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | adrar
# Processing Record 10 of Set 5 | sotouboua
# Processing Record 11 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 5 | idrinskoye
# Processing Record 13 of Set 5 | ascension
# Processing Record 14 of Set 5 | tulum
# Processing Record 15 of Set 5 | zainsk
# Processing Record 16 of Set 5 | husavik
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | esperance
# Processing Record 22 of Set 5 | rutana
# Processing Record 23 of Set 5 | zhangye
# Processing Record 24 of Set 5 | viransehir
# Processing Record 25 of Set 5 | byron bay
# Processing Record 26 of Set 5 | zwedru
# Processing Record 27 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | dikson
# Processing Record 30 of Set 5 | ndola
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | talaya
# Processing Record 33 of Set 5 | neuquen
# Processing Record 34 of Set 5 | ponta do sol
# Processing Record 35 of Set 5 | port-cartier
# Processing Record 36 of Set 5 | codrington
# Processing Record 37 of Set 5 | vila franca do campo
# Processing Record 38 of Set 5 | alexandria
# Processing Record 39 of Set 5 | khandbari
# Processing Record 40 of Set 5 | seddon
# Processing Record 41 of Set 5 | vilhena
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | novotalitsy
# City not found. Skipping...
# Processing Record 45 of Set 5 | sandwick
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | kavieng
# Processing Record 48 of Set 5 | bosanski novi
# Processing Record 49 of Set 5 | vylkove
# Processing Record 50 of Set 5 | ayios matthaios
# City not found. Skipping...
# Processing Record 1 of Set 6 | aykhal
# Processing Record 2 of Set 6 | whitehorse
# Processing Record 3 of Set 6 | hithadhoo
# Processing Record 4 of Set 6 | denpasar
# Processing Record 5 of Set 6 | ulaangom
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | waitara
# Processing Record 8 of Set 6 | brigantine
# Processing Record 9 of Set 6 | melita
# Processing Record 10 of Set 6 | puerto del rosario
# Processing Record 11 of Set 6 | nanlong
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | san clemente
# Processing Record 14 of Set 6 | thunder bay
# Processing Record 15 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 6 | madison
# Processing Record 17 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 6 | svetlogorsk
# Processing Record 19 of Set 6 | viedma
# Processing Record 20 of Set 6 | nizhniy baskunchak
# Processing Record 21 of Set 6 | naryan-mar
# Processing Record 22 of Set 6 | astoria
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | cidreira
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | namibe
# Processing Record 27 of Set 6 | kogon
# Processing Record 28 of Set 6 | buala
# Processing Record 29 of Set 6 | jalu
# Processing Record 30 of Set 6 | dwarka
# Processing Record 31 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 6 | san ramon
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | beni mazar
# Processing Record 35 of Set 6 | beloha
# Processing Record 36 of Set 6 | muros
# Processing Record 37 of Set 6 | poum
# Processing Record 38 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | west plains
# Processing Record 41 of Set 6 | mogadishu
# Processing Record 42 of Set 6 | zhuhai
# Processing Record 43 of Set 6 | arua
# Processing Record 44 of Set 6 | kholm
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | omutinskoye
# City not found. Skipping...
# Processing Record 47 of Set 6 | soyo
# Processing Record 48 of Set 6 | ocara
# Processing Record 49 of Set 6 | otjimbingwe
# Processing Record 50 of Set 6 | kuusamo
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | skjervoy
# Processing Record 4 of Set 7 | clyde river
# Processing Record 5 of Set 7 | severo-kurilsk
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | filingue
# Processing Record 8 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 9 of Set 7 | sembe
# Processing Record 10 of Set 7 | oxford
# Processing Record 11 of Set 7 | eucaliptus
# Processing Record 12 of Set 7 | healdsburg
# Processing Record 13 of Set 7 | zhigansk
# Processing Record 14 of Set 7 | mareeba
# Processing Record 15 of Set 7 | kudahuvadhoo
# Processing Record 16 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 7 | meulaboh
# Processing Record 18 of Set 7 | ulagan
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | ust-kuyga
# Processing Record 23 of Set 7 | aripuana
# Processing Record 24 of Set 7 | feira de santana
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | kelso
# Processing Record 27 of Set 7 | port shepstone
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | simplicio mendes
# Processing Record 30 of Set 7 | iqaluit
# Processing Record 31 of Set 7 | dustlik
# Processing Record 32 of Set 7 | taos
# Processing Record 33 of Set 7 | vostok
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | tuatapere
# Processing Record 36 of Set 7 | margate
# Processing Record 37 of Set 7 | kimbe
# Processing Record 38 of Set 7 | mount pleasant
# Processing Record 39 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 7 | mount isa
# Processing Record 41 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 7 | honiara
# Processing Record 43 of Set 7 | banjar
# Processing Record 44 of Set 7 | roma
# Processing Record 45 of Set 7 | yian
# City not found. Skipping...
# Processing Record 46 of Set 7 | havre-saint-pierre
# Processing Record 47 of Set 7 | lota
# Processing Record 48 of Set 7 | taga
# Processing Record 49 of Set 7 | lakselv
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | laguna
# Processing Record 2 of Set 8 | aswan
# Processing Record 3 of Set 8 | gbarnga
# Processing Record 4 of Set 8 | flin flon
# Processing Record 5 of Set 8 | sechura
# Processing Record 6 of Set 8 | sibu
# Processing Record 7 of Set 8 | kathmandu
# Processing Record 8 of Set 8 | bridlington
# Processing Record 9 of Set 8 | vestmannaeyjar
# Processing Record 10 of Set 8 | kangaba
# Processing Record 11 of Set 8 | opuwo
# Processing Record 12 of Set 8 | yerofey pavlovich
# Processing Record 13 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 8 | homberg
# Processing Record 15 of Set 8 | easton
# Processing Record 16 of Set 8 | raga
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 8 | tlaxco
# Processing Record 20 of Set 8 | russell
# Processing Record 21 of Set 8 | rocha
# Processing Record 22 of Set 8 | stantsionno-oyashinskiy
# Processing Record 23 of Set 8 | kalisz
# Processing Record 24 of Set 8 | saskylakh
# Processing Record 25 of Set 8 | nogliki
# Processing Record 26 of Set 8 | dzilam gonzalez
# Processing Record 27 of Set 8 | leeuwarden
# Processing Record 28 of Set 8 | shubarkuduk
# Processing Record 29 of Set 8 | sao jose da coroa grande
# Processing Record 30 of Set 8 | hualmay
# Processing Record 31 of Set 8 | puerto escondido
# Processing Record 32 of Set 8 | morgan city
# Processing Record 33 of Set 8 | talnakh
# Processing Record 34 of Set 8 | harper
# Processing Record 35 of Set 8 | akhalgori
# Processing Record 36 of Set 8 | launceston
# Processing Record 37 of Set 8 | avera
# Processing Record 38 of Set 8 | inhambane
# Processing Record 39 of Set 8 | nantucket
# Processing Record 40 of Set 8 | lompoc
# Processing Record 41 of Set 8 | bud
# Processing Record 42 of Set 8 | sarangani
# Processing Record 43 of Set 8 | espanola
# Processing Record 44 of Set 8 | kununurra
# Processing Record 45 of Set 8 | kakonko
# Processing Record 46 of Set 8 | mackay
# Processing Record 47 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 8 | maxixe
# Processing Record 49 of Set 8 | sola
# Processing Record 50 of Set 8 | kieta
# Processing Record 1 of Set 9 | kamenskiy
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | college
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | lakes entrance
# Processing Record 6 of Set 9 | karaton
# Processing Record 7 of Set 9 | bathsheba
# Processing Record 8 of Set 9 | listvyanka
# Processing Record 9 of Set 9 | isangel
# Processing Record 10 of Set 9 | cape canaveral
# Processing Record 11 of Set 9 | seoul
# Processing Record 12 of Set 9 | tsuruoka
# Processing Record 13 of Set 9 | qandala
# Processing Record 14 of Set 9 | pemberton
# Processing Record 15 of Set 9 | camopi
# Processing Record 16 of Set 9 | krasnoselkup
# Processing Record 17 of Set 9 | kissidougou
# Processing Record 18 of Set 9 | da nang
# Processing Record 19 of Set 9 | yerbogachen
# Processing Record 20 of Set 9 | tambopata
# Processing Record 21 of Set 9 | brenham
# Processing Record 22 of Set 9 | saint-joseph
# Processing Record 23 of Set 9 | seleron
# Processing Record 24 of Set 9 | bria
# Processing Record 25 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 9 | uusikaupunki
# Processing Record 27 of Set 9 | terney
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | la reforma
# Processing Record 30 of Set 9 | yayva
# Processing Record 31 of Set 9 | paracuru
# Processing Record 32 of Set 9 | cockburn town
# Processing Record 33 of Set 9 | tromso
# Processing Record 34 of Set 9 | kumluca
# Processing Record 35 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 36 of Set 9 | buraydah
# Processing Record 37 of Set 9 | fortuna
# Processing Record 38 of Set 9 | howard springs
# Processing Record 39 of Set 9 | kyshtovka
# Processing Record 40 of Set 9 | champerico
# Processing Record 41 of Set 9 | korla
# Processing Record 42 of Set 9 | cherskiy
# Processing Record 43 of Set 9 | virginia beach
# Processing Record 44 of Set 9 | nara
# Processing Record 45 of Set 9 | dakar
# Processing Record 46 of Set 9 | pokhara
# Processing Record 47 of Set 9 | batagay-alyta
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | manadhoo
# Processing Record 50 of Set 9 | tessalit
# Processing Record 1 of Set 10 | aketi
# Processing Record 2 of Set 10 | newport
# Processing Record 3 of Set 10 | annau
# Processing Record 4 of Set 10 | fairview shores
# Processing Record 5 of Set 10 | ust-ilimsk
# Processing Record 6 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 7 of Set 10 | katobu
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | constitucion
# Processing Record 11 of Set 10 | namatanai
# Processing Record 12 of Set 10 | palafrugell
# Processing Record 13 of Set 10 | ayagoz
# Processing Record 14 of Set 10 | bakel
# Processing Record 15 of Set 10 | katangli
# Processing Record 16 of Set 10 | cap-aux-meules
# Processing Record 17 of Set 10 | tilichiki
# Processing Record 18 of Set 10 | rassvet
# Processing Record 19 of Set 10 | revuca
# Processing Record 20 of Set 10 | ilulissat
# Processing Record 21 of Set 10 | fort nelson
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 10 | zelenoborskiy
# Processing Record 25 of Set 10 | manokwari
# Processing Record 26 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 27 of Set 10 | jambi
# Processing Record 28 of Set 10 | vao
# Processing Record 29 of Set 10 | linjiang
# Processing Record 30 of Set 10 | san bartolome de tirajana
# Processing Record 31 of Set 10 | lagoa
# Processing Record 32 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 10 | macon
# Processing Record 34 of Set 10 | alekseyevsk
# Processing Record 35 of Set 10 | sagua de tanamo
# Processing Record 36 of Set 10 | smithers
# Processing Record 37 of Set 10 | cabra
# Processing Record 38 of Set 10 | camacha
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | acapulco
# Processing Record 41 of Set 10 | kemijarvi
# Processing Record 42 of Set 10 | thaba nchu
# Processing Record 43 of Set 10 | labuhan
# Processing Record 44 of Set 10 | polewali
# Processing Record 45 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 46 of Set 10 | lamu
# Processing Record 47 of Set 10 | puerto ayacucho
# Processing Record 48 of Set 10 | candelaria
# Processing Record 49 of Set 10 | kitimat
# Processing Record 50 of Set 10 | okahandja
# Processing Record 1 of Set 11 | general pico
# Processing Record 2 of Set 11 | kampot
# Processing Record 3 of Set 11 | shimoda
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | houma
# Processing Record 6 of Set 11 | lima
# Processing Record 7 of Set 11 | bajil
# Processing Record 8 of Set 11 | santiago del estero
# Processing Record 9 of Set 11 | trowbridge
# Processing Record 10 of Set 11 | pafos
# Processing Record 11 of Set 11 | thinadhoo
# Processing Record 12 of Set 11 | papara
# Processing Record 13 of Set 11 | san angelo
# Processing Record 14 of Set 11 | lindi
# Processing Record 15 of Set 11 | amga
# Processing Record 16 of Set 11 | manoel urbano
# Processing Record 17 of Set 11 | hovd
# Processing Record 18 of Set 11 | malihabad
# Processing Record 19 of Set 11 | shingu
# Processing Record 20 of Set 11 | baykit
# Processing Record 21 of Set 11 | ancud
# Processing Record 22 of Set 11 | portland
# Processing Record 23 of Set 11 | kruisfontein
# Processing Record 24 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 11 | poronaysk
# Processing Record 26 of Set 11 | bulalacao
# Processing Record 27 of Set 11 | akyab
# Processing Record 28 of Set 11 | khash
# Processing Record 29 of Set 11 | careiro da varzea
# Processing Record 30 of Set 11 | xinan
# Processing Record 31 of Set 11 | taybad
# Processing Record 32 of Set 11 | kincardine
# Processing Record 33 of Set 11 | riyadh
# Processing Record 34 of Set 11 | bembereke
# Processing Record 35 of Set 11 | wahiawa
# Processing Record 36 of Set 11 | igaracu do tiete
# Processing Record 37 of Set 11 | lichtenburg
# Processing Record 38 of Set 11 | ushibuka
# Processing Record 39 of Set 11 | charters towers
# Processing Record 40 of Set 11 | khasan
# Processing Record 41 of Set 11 | wajid
# Processing Record 42 of Set 11 | bilma
# Processing Record 43 of Set 11 | yatou
# Processing Record 44 of Set 11 | los llanos de aridane
# Processing Record 45 of Set 11 | puerto madero
# Processing Record 46 of Set 11 | buchanan
# Processing Record 47 of Set 11 | seabra
# Processing Record 48 of Set 11 | sibolga
# Processing Record 49 of Set 11 | macia
# Processing Record 50 of Set 11 | safaga
# Processing Record 1 of Set 12 | creston
# Processing Record 2 of Set 12 | caconda
# Processing Record 3 of Set 12 | aljezur
# Processing Record 4 of Set 12 | coihaique
# Processing Record 5 of Set 12 | ventspils
# Processing Record 6 of Set 12 | egvekinot
# Processing Record 7 of Set 12 | san pedro
# Processing Record 8 of Set 12 | evensk
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | kenai
# Processing Record 11 of Set 12 | leon
# Processing Record 12 of Set 12 | san juan bautista
# Processing Record 13 of Set 12 | sandavagur
# City not found. Skipping...
# Processing Record 14 of Set 12 | gimli
# Processing Record 15 of Set 12 | tarakan
# Processing Record 16 of Set 12 | komsomolskiy
# Processing Record 17 of Set 12 | san matias
# Processing Record 18 of Set 12 | gayeri
# Processing Record 19 of Set 12 | bhikhi
# Processing Record 20 of Set 12 | sergeyevka
# Processing Record 21 of Set 12 | porto walter
# Processing Record 22 of Set 12 | buin
# Processing Record 23 of Set 12 | praya
# Processing Record 24 of Set 12 | zonguldak
# Processing Record 25 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 12 | viseu
# Processing Record 27 of Set 12 | paka
# Processing Record 28 of Set 12 | yarada
# Processing Record 29 of Set 12 | sioux lookout
# Processing Record 30 of Set 12 | tingi
# Processing Record 31 of Set 12 | nichinan
# Processing Record 32 of Set 12 | sheridan
# Processing Record 33 of Set 12 | svetlyy
# Processing Record 34 of Set 12 | najran
# Processing Record 35 of Set 12 | wamba
# Processing Record 36 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 12 | chala
# Processing Record 38 of Set 12 | guamuchil
# Processing Record 39 of Set 12 | maningrida
# Processing Record 40 of Set 12 | fare
# Processing Record 41 of Set 12 | santa isabel
# Processing Record 42 of Set 12 | moreira sales
# Processing Record 43 of Set 12 | harlingen
# Processing Record 44 of Set 12 | kaspiyskiy
# Processing Record 45 of Set 12 | solnechnyy
# Processing Record 46 of Set 12 | novoagansk
# Processing Record 47 of Set 12 | buritis
# Processing Record 48 of Set 12 | marshfield
# Processing Record 49 of Set 12 | verin
# Processing Record 50 of Set 12 | bowen
# Processing Record 1 of Set 13 | lumsden
# Processing Record 2 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 13 | lagos
# Processing Record 4 of Set 13 | pemangkat
# Processing Record 5 of Set 13 | palkaka
# City not found. Skipping...
# Processing Record 6 of Set 13 | porto novo
# Processing Record 7 of Set 13 | menongue
# Processing Record 8 of Set 13 | vetlanda
# Processing Record 9 of Set 13 | port hardy
# Processing Record 10 of Set 13 | flinders
# Processing Record 11 of Set 13 | necochea
# Processing Record 12 of Set 13 | mastung
# Processing Record 13 of Set 13 | psedakh
# Processing Record 14 of Set 13 | port moresby
# Processing Record 15 of Set 13 | northam
# Processing Record 16 of Set 13 | nilo
# Processing Record 17 of Set 13 | san lawrenz
# Processing Record 18 of Set 13 | catamarca
# Processing Record 19 of Set 13 | omsukchan
# Processing Record 20 of Set 13 | unai
# Processing Record 21 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 13 | durban
# Processing Record 23 of Set 13 | carballo
# Processing Record 24 of Set 13 | jiamusi
# Processing Record 25 of Set 13 | urumqi
# Processing Record 26 of Set 13 | biak
# Processing Record 27 of Set 13 | ust-tsilma
# Processing Record 28 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 13 | siemiatycze
# Processing Record 31 of Set 13 | islampur
# Processing Record 32 of Set 13 | port hedland
# Processing Record 33 of Set 13 | pueblo
# Processing Record 34 of Set 13 | pyinmana
# Processing Record 35 of Set 13 | gushikawa
# Processing Record 36 of Set 13 | luzzi
# Processing Record 37 of Set 13 | serebryansk
# Processing Record 38 of Set 13 | sisimiut
# Processing Record 39 of Set 13 | broken hill
# Processing Record 40 of Set 13 | bonavista
# Processing Record 41 of Set 13 | birin
# Processing Record 42 of Set 13 | messina
# Processing Record 43 of Set 13 | buncrana
# Processing Record 44 of Set 13 | kaduy
# Processing Record 45 of Set 13 | saint-pierre
# Processing Record 46 of Set 13 | berlevag
# Processing Record 47 of Set 13 | andra
# Processing Record 48 of Set 13 | hirara
# Processing Record 49 of Set 13 | manta
# Processing Record 50 of Set 13 | floro
# Processing Record 1 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 14 | sawakin
# Processing Record 4 of Set 14 | bertoua
# Processing Record 5 of Set 14 | upanema
# Processing Record 6 of Set 14 | nyurba
# Processing Record 7 of Set 14 | jibuti
# Processing Record 8 of Set 14 | bintulu
# Processing Record 9 of Set 14 | naze
# Processing Record 10 of Set 14 | terre-de-bas
# Processing Record 11 of Set 14 | turukhansk
# Processing Record 12 of Set 14 | pachino
# Processing Record 13 of Set 14 | chanderi
# Processing Record 14 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 14 | wajir
# Processing Record 16 of Set 14 | laem sing
# Processing Record 17 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 14 | sawtell
# Processing Record 19 of Set 14 | aragarcas
# Processing Record 20 of Set 14 | kalabo
# Processing Record 21 of Set 14 | houston
# Processing Record 22 of Set 14 | mwinilunga
# Processing Record 23 of Set 14 | praia da vitoria
# Processing Record 24 of Set 14 | touros
# Processing Record 25 of Set 14 | kofele
# Processing Record 26 of Set 14 | babstovo
# Processing Record 27 of Set 14 | anan
# Processing Record 28 of Set 14 | tazovskiy
# Processing Record 29 of Set 14 | rusape
# Processing Record 30 of Set 14 | kanigoro
# Processing Record 31 of Set 14 | arraias
# Processing Record 32 of Set 14 | sambava
# Processing Record 33 of Set 14 | mehamn
# Processing Record 34 of Set 14 | araouane
# Processing Record 35 of Set 14 | bandrele
# Processing Record 36 of Set 14 | ovalle
# Processing Record 37 of Set 14 | garden city
# Processing Record 38 of Set 14 | ciudad bolivar
# Processing Record 39 of Set 14 | havelock
# Processing Record 40 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 14 | cape coast
# Processing Record 42 of Set 14 | montepuez
# Processing Record 43 of Set 14 | saa
# Processing Record 44 of Set 14 | altagracia de orituco
# Processing Record 45 of Set 14 | genhe
# Processing Record 46 of Set 14 | moreira
# Processing Record 47 of Set 14 | kaura namoda
# Processing Record 48 of Set 14 | maraa
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | goundi
# Processing Record 1 of Set 15 | alpena
# Processing Record 2 of Set 15 | varca
# Processing Record 3 of Set 15 | fuerte olimpo
# Processing Record 4 of Set 15 | pogar
# Processing Record 5 of Set 15 | esna
# Processing Record 6 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 15 | coxquihui
# Processing Record 8 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 15 | noumea
# Processing Record 10 of Set 15 | stuttgart
# Processing Record 11 of Set 15 | ovsyanka
# Processing Record 12 of Set 15 | paide
# Processing Record 13 of Set 15 | azare
# Processing Record 14 of Set 15 | mae hong son
# Processing Record 15 of Set 15 | la ermita
# Processing Record 16 of Set 15 | paz de ariporo
# City not found. Skipping...
# Processing Record 17 of Set 15 | wagar
# Processing Record 18 of Set 15 | ola
# Processing Record 19 of Set 15 | grafton
# Processing Record 20 of Set 15 | cheremukhovo
# Processing Record 21 of Set 15 | abohar
# Processing Record 22 of Set 15 | cumberland
# Processing Record 23 of Set 15 | hervey bay
# Processing Record 24 of Set 15 | ocampo
# Processing Record 25 of Set 15 | aktash
# Processing Record 26 of Set 15 | wundanyi
# Processing Record 27 of Set 15 | ushtobe
# Processing Record 28 of Set 15 | wardha
# Processing Record 29 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 30 of Set 15 | southbridge
# Processing Record 31 of Set 15 | tsagan aman
# Processing Record 32 of Set 15 | mukhen
# Processing Record 33 of Set 15 | marinette
# Processing Record 34 of Set 15 | tharrawaddy
# City not found. Skipping...
# Processing Record 35 of Set 15 | liverpool
# Processing Record 36 of Set 15 | valparaiso
# Processing Record 37 of Set 15 | roebourne
# Processing Record 38 of Set 15 | la ronge
# Processing Record 39 of Set 15 | sweetwater
# Processing Record 40 of Set 15 | enumclaw
# Processing Record 41 of Set 15 | ambulu
# Processing Record 42 of Set 15 | dunedin
# Processing Record 43 of Set 15 | manakara
# Processing Record 44 of Set 15 | porto velho
# Processing Record 45 of Set 15 | ahipara
# Processing Record 46 of Set 15 | katherine
# Processing Record 47 of Set 15 | nanortalik
# Processing Record 48 of Set 15 | caravelas
# Processing Record 49 of Set 15 | porto torres
# Processing Record 50 of Set 15 | santo amaro da imperatriz
# Processing Record 1 of Set 16 | paamiut
# Processing Record 2 of Set 16 | zharkent
# Processing Record 3 of Set 16 | manaus
# Processing Record 4 of Set 16 | ape
# Processing Record 5 of Set 16 | kailua
# Processing Record 6 of Set 16 | mandalgovi
# Processing Record 7 of Set 16 | benguela
# Processing Record 8 of Set 16 | valdivia
# Processing Record 9 of Set 16 | fountain hills
# Processing Record 10 of Set 16 | chadiza
# Processing Record 11 of Set 16 | dahra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     49.66        76          75       17.27
# 1      Mataura -46.1927  168.8643     41.49        81           0        1.74
# 2     Hermanus -34.4187   19.2345     61.81        89          36        8.46
# 3        Kidal  18.4411    1.4078     80.62        14          98       10.07
# 4   Nouadhibou  20.9310  -17.0347     65.21        91         100       12.57
# 5       Broome  42.2506  -75.8330     44.71        46         100       19.57
# 6   Chokurdakh  70.6333  147.9167     -1.16        99          91        4.36
# 7    Jamestown  42.0970  -79.2353     43.02        40           0        6.91
# 8       Bethel  41.3712  -73.4140     49.53        42          20       13.80
# 9  East London -33.0153   27.9116     64.92        81          76        5.82
#
#                Description Country                 Date
# 0  light intensity drizzle      AR  2022-04-17 21:07:12
# 1                clear sky      NZ  2022-04-17 21:07:13
# 2         scattered clouds      ZA  2022-04-17 21:07:13
# 3          overcast clouds      ML  2022-04-17 21:07:13
# 4          overcast clouds      MR  2022-04-17 21:07:14
# 5          overcast clouds      US  2022-04-17 21:07:14
# 6          overcast clouds      RU  2022-04-17 21:07:15
# 7                clear sky      US  2022-04-17 21:07:15
# 8               few clouds      US  2022-04-17 21:07:15
# 9            broken clouds      ZA  2022-04-17 21:07:14

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000  -68.3000     49.66        76          75
# 1      Mataura      NZ -46.1927  168.8643     41.49        81           0
# 2     Hermanus      ZA -34.4187   19.2345     61.81        89          36
# 3        Kidal      ML  18.4411    1.4078     80.62        14          98
# 4   Nouadhibou      MR  20.9310  -17.0347     65.21        91         100
# 5       Broome      US  42.2506  -75.8330     44.71        46         100
# 6   Chokurdakh      RU  70.6333  147.9167     -1.16        99          91
# 7    Jamestown      US  42.0970  -79.2353     43.02        40           0
# 8       Bethel      US  41.3712  -73.4140     49.53        42          20
# 9  East London      ZA -33.0153   27.9116     64.92        81          76
#
#    Wind Speed              Description
# 0       17.27  light intensity drizzle
# 1        1.74                clear sky
# 2        8.46         scattered clouds
# 3       10.07          overcast clouds
# 4       12.57          overcast clouds
# 5       19.57          overcast clouds
# 6        4.36          overcast clouds
# 7        6.91                clear sky
# 8       13.80               few clouds
# 9        5.82            broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
